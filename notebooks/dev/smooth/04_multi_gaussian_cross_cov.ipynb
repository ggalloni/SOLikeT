# %% [markdown]
# # Multi-Gaussian Cross-Covariance Tests
#
# Tests for cross-covariance handling between mflike and lensing.

# %% [markdown]
# **Note:** Run `01_multi_gaussian_setup.ipynb` first, or copy the setup cells from it.

# %%
# %matplotlib inline
# import tempfile

import os

import camb
import cobaya
import matplotlib as mpl
import numpy as np
from cobaya.tools import resolve_packages_path

print("     Numpy :", np.__version__)
print("Matplotlib :", mpl.__version__)
print("      CAMB :", camb.__version__)
print("    Cobaya :", cobaya.__version__)

# %%
# Fiducial cosmo params. When used in a MCMC, the smooth data must agree
# with this input values

cosmo_params = {
    "cosmomc_theta": 0.0104090,
    "logA": {"value": 3.045, "drop": True},
    "As": {"value": "lambda logA: 1e-10*np.exp(logA)"},
    "ombh2": 0.02236,
    "omch2": 0.1202,
    "ns": 0.9649,
    "Alens": 1.0,
    "tau": 0.0544,
    "mnu": 0.06,
    "nnu": 3.044,
}

common_nuis_params = {
    "T_effd": 19.6,
    "beta_d": 1.5,
    "beta_s": -2.5,
    "alpha_s": 1,
    "bandint_shift_LAT_93": 0,  # only ideal values for now
    "bandint_shift_LAT_145": 0,
    "bandint_shift_LAT_225": 0,
    "cal_LAT_93": 1,
    "cal_LAT_145": 1,
    "cal_LAT_225": 1,
    "calG_all": 1,
    "alpha_LAT_93": 0,
    "alpha_LAT_145": 0,
    "alpha_LAT_225": 0,
}

TT_nuis_params = {
    "a_tSZ": 3.30,
    "a_kSZ": 1.60,
    "a_p": 6.90,
    "beta_p": 2.08,
    "a_c": 4.90,
    "beta_c": 2.20,
    "a_s": 3.10,
    "T_d": 9.60,
    "a_gtt": 2.81,
    "xi": 0.20,
    "alpha_dT": -0.6,
    "alpha_p": 1,
    "alpha_tSZ": 0.0,
    "calT_LAT_93": 1,
    "calT_LAT_145": 1,
    "calT_LAT_225": 1,
}

TE_nuis_params = {
    "a_gte": 0.10,
    "a_pste": 0,
    "alpha_dE": -0.4,
}

EE_nuis_params = {
    "a_gee": 0.10,
    "a_psee": 0,
    "alpha_dE": -0.4,
    "calE_LAT_93": 1,
    "calE_LAT_145": 1,
    "calE_LAT_225": 1,
}

# %%
custom_packages_path = None

# Try to resolve global path
if custom_packages_path is None:
    packages_path = resolve_packages_path()
else:
    packages_path = custom_packages_path

# %%
namedir = packages_path + "/data/soliket_mflike/smooth_data/split_mflike/"
pre = "data_sacc_"
mflike_options = {
    "data_folder": namedir,
    "input_file": pre + "smooth_00000.fits",
    "cov_Bbl_file": packages_path + "/data/MFLike/v0.8/data_sacc_w_covar_and_Bbl.fits",
    "defaults": {
        "polarizations": ["TT", "TE", "ET", "EE"],
        "scales": {
            "TT": [30, 9000],
            "TE": [30, 9000],
            "ET": [30, 9000],
            "EE": [30, 9000],
        },
        "symmetrize": False,
    },
}

lensing_options = {
    "data_filename": "soliket_lensing/smooth_data/clkk_reconstruction_sim_smooth.fits",
    "theory_lmax": 5000,
    "stop_at_error": True,
}

info_multi = {
    "likelihood": {
        "soliket.gaussian.MultiGaussianLikelihood": {
            "components": ["mflike.TTTEEE", "soliket.LensingLikelihood"],
            "options": [mflike_options, lensing_options],
            "stop_at_error": True,
        }
    },
    "theory": {
        "camb": {
            "extra_args": {
                "bbn_predictor": "PArthENoPE_880.2_standard.dat",
                "WantTransfer": True,
                "Transfer.high_precision": True,
                "Transfer.kmax": 1.2,
                "halofit_version": "mead",
                "lens_potential_accuracy": 1,
                "num_massive_neutrinos": 1,
                "theta_H0_range": [20, 100],
            },
            "stop_at_error": True,
        }
    },
    "params": cosmo_params
    | common_nuis_params
    | TT_nuis_params
    | TE_nuis_params
    | EE_nuis_params,
    "packages_path": packages_path,
    "debug": False,
}
info_multi["theory"]["mflike.BandpowerForeground"] = {"stop_at_error": True}

# %%
from cobaya.model import get_model

model_multi = get_model(info_multi)

# %%
model_multi.loglikes()

# %%
model_multi.components

# %%
Dl = model_multi.components[2].get_Cl(ell_factor=True)
fg_totals = model_multi.components[3].get_fg_totals()

# %%
params = {
    **cosmo_params,
    **common_nuis_params,
    **TT_nuis_params,
    **EE_nuis_params,
    **TE_nuis_params,
}

# %%
mflike = model_multi.components[0].likelihoods[0]
dls = {s: Dl[s][mflike.l_bpws] for s, _ in mflike.lcuts.items()}
# combine CMB and FG and add svstematics
DlsObs = mflike.get_modified_theory(dls, fg_totals, **params)

# %%
ps_dic = {}
ps_vec = np.zeros_like(mflike.data_vec)

for m in mflike.spec_meta:
    p = m["pol"]
    ids = m["ids"]
    w = m["bpw"]
    t1 = m["t1"]
    t2 = m["t2"]

    # print(p, ids, t1, t2)
    if t1 + "x" + t2 not in ps_dic.keys():
        ps_dic[t1 + "x" + t2] = {"lbin": m["leff"]}

    dls_obs = (
        DlsObs[p, m["t2"], m["t1"]] if m["hasYX_xsp"] else DlsObs[p, m["t1"], m["t2"]]
    )
    for i, nonzero, weights in zip(m["ids"], w.nonzeros, w.sliced_weights):
        ps_vec[i] = weights @ dls_obs[nonzero]

    ps_dic[t1 + "x" + t2].update({p: ps_vec[ids]})

# %%
ps_dic.keys()  # check that all spectra are here

# %%
namedir = packages_path + "/data/soliket_mflike/smooth_data/split_mflike/"
os.makedirs(namedir, exist_ok=True)

for k in ps_dic.keys():
    namefile = "Dl_frommulti_" + k + "_auto_00000.dat"
    ll = ps_dic[k]["lbin"]
    tt = ps_dic[k]["tt"]
    te = ps_dic[k]["te"]
    ee = ps_dic[k]["ee"]
    tbebbb = np.zeros(len(ll))
    np.savetxt(
        namedir + namefile,
        np.column_stack((ll, tt, te, tbebbb, te, tbebbb, ee, tbebbb, tbebbb, tbebbb)),
    )

# %%
cltest = np.loadtxt(namedir + namefile)
cltest.shape

# %%
data = {}
sim_suffix = "00000"
for spec_name in ps_dic.keys():
    na, nb = spec_name.split("x")
    data[na, nb] = {}
    spec = np.loadtxt(
        "%s/Dl_frommulti_%s_auto_%s.dat" % (namedir, spec_name, sim_suffix), unpack=True
    )
    ps = {
        "lbin": spec[0],
        "TT": spec[1],
        "TE": spec[2],
        "TB": spec[3],
        "ET": spec[4],
        "BT": spec[5],
        "EE": spec[6],
        "EB": spec[7],
        "BE": spec[8],
        "BB": spec[9],
    }
    data[na, nb] = ps

# %%
exp_freq = ["LAT_93", "LAT_145", "LAT_225"]
pols = ["T", "E", "B"]
map_types = {"T": "0", "E": "e", "B": "b"}


def get_x_iterator():
    for id_efa, efa in enumerate(exp_freq):
        for id_efb, efb in enumerate(exp_freq):
            if id_efa > id_efb:
                continue
            for ipa, pa in enumerate(pols):
                if efa == efb:
                    polsb = pols[ipa:]
                else:
                    polsb = pols
                for pb in polsb:
                    yield (efa, efb, pa, pb)
                    print(efa, efb, pa, pb)

# %%
import sacc

spec_sacc = sacc.Sacc()

# %%
for exp_f in exp_freq:
    print("%s_s0" % (exp_f))

    my_data_bandpasses = {
        "nu": np.array([float(exp_f.split("_")[1])]),
        "b_nu": np.array([1.0]),
    }
    my_data_beams = {"l": np.arange(10000), "bl": np.ones(10000)}

    # CMB temperature
    spec_sacc.add_tracer(
        "NuMap",
        "%s_s0" % (exp_f),
        quantity="cmb_temperature",
        spin=0,
        nu=mflike.bands[exp_f + "_s0"]["nu"],
        bandpass=mflike.bands[exp_f + "_s0"]["bandpass"],
        ell=my_data_beams["l"],
        beam=my_data_beams["bl"],
    )

    # CMB polarization
    spec_sacc.add_tracer(
        "NuMap",
        "%s_s2" % (exp_f),
        quantity="cmb_polarization",
        spin=2,
        nu=mflike.bands[exp_f + "_s2"]["nu"],
        bandpass=mflike.bands[exp_f + "_s2"]["bandpass"],
        ell=my_data_beams["l"],
        beam=my_data_beams["bl"],
    )

# %%
for id_x, (efa, efb, pa, pb) in enumerate(get_x_iterator()):
    if pa == "T":
        ta_name = "%s_s0" % (efa)
    else:
        ta_name = "%s_s2" % (efa)

    if pb == "T":
        tb_name = "%s_s0" % (efb)
    else:
        tb_name = "%s_s2" % (efb)

    if pb == "T":
        cl_type = "cl_" + map_types[pb] + map_types[pa]
    else:
        cl_type = "cl_" + map_types[pa] + map_types[pb]

    lbin = data[efa, efb]["lbin"]
    cb = data[efa, efb][pa + pb]

    spec_sacc.add_ell_cl(cl_type, ta_name, tb_name, lbin, cb)

# %%
spec_sacc.save_fits("%s/data_sacc_smooth_%s.fits" % (namedir, sim_suffix), overwrite=True)

# %%
sacc_data = sacc.Sacc.load_fits(
    packages_path + "/data/LensingLikelihood/lensing.sacc.fits"
)

ell, clkk, cov, ind = sacc_data.get_ell_cl(
    "cl_00", "ck", "ck", return_cov=True, return_ind=True
)
wins = sacc_data.get_bandpower_windows(ind)

print(sacc_data.metadata)
print(sacc_data.tracers)

# %%
lensing = model_multi.components[0].likelihoods[1]

# %%
s = sacc.Sacc()
s.metadata["info"] = "CMB lensing power spectra from reconstruction simulations"

beam = np.ones_like(ell)

s.add_tracer(
    tracer_type="Map",
    name="ck",
    quantity="cmb_convergence",
    spin=0,
    map_unit="uK_CMB",
    ell=ell,
    beam=beam,
)

s.add_ell_cl(
    "cl_00",  # Data type
    "ck",  # 1st tracer's name
    "ck",  # 2nd tracer's name
    ell,  # Effective multipole
    lensing._get_theory(**cosmo_params),  # Power spectrum values
    window=wins,  # Bandpower windows
)

cov = sacc.covariance.FullCovariance.from_hdu(cov)
s.add_covariance(cov, overwrite=False)

ndir = (
    packages_path
    + "/data/LensingLikelihood/soliket_lensing/smooth_data/"
    + "clkk_reconstruction_sim_frommulti_smooth.fits"
)

os.makedirs(
    packages_path + "/data/LensingLikelihood/soliket_lensing/smooth_data/",
    exist_ok=True,
)
s.save_fits(ndir, overwrite=True)

# %% [markdown]
# # Use with cross-covariance

# %%
# Fiducial cosmo params. When used in a MCMC, the smooth data must agree
# with this input values

cosmo_params = {
    "cosmomc_theta": 0.0104090,
    "logA": {"value": 3.045, "drop": True},
    "As": {"value": "lambda logA: 1e-10*np.exp(logA)"},
    "ombh2": 0.02236,
    "omch2": 0.1202,
    "ns": 0.9649,
    "Alens": 1.0,
    "tau": 0.0544,
    "mnu": 0.06,
    "nnu": 3.044,
}

common_nuis_params = {
    "T_effd": 19.6,
    "beta_d": 1.5,
    "beta_s": -2.5,
    "alpha_s": 1,
    "bandint_shift_LAT_93": 0,  # only ideal values for now
    "bandint_shift_LAT_145": 0,
    "bandint_shift_LAT_225": 0,
    "cal_LAT_93": 1,
    "cal_LAT_145": 1,
    "cal_LAT_225": 1,
    "calG_all": 1,
    "alpha_LAT_93": 0,
    "alpha_LAT_145": 0,
    "alpha_LAT_225": 0,
}

TT_nuis_params = {
    "a_tSZ": 3.30,
    "a_kSZ": 1.60,
    "a_p": 6.90,
    "beta_p": 2.08,
    "a_c": 4.90,
    "beta_c": 2.20,
    "a_s": 3.10,
    "T_d": 9.60,
    "a_gtt": 2.81,
    "xi": 0.20,
    "alpha_dT": -0.6,
    "alpha_p": 1,
    "alpha_tSZ": 0.0,
    "calT_LAT_93": 1,
    "calT_LAT_145": 1,
    "calT_LAT_225": 1,
}

TE_nuis_params = {
    "a_gte": 0.10,
    "a_pste": 0,
    "alpha_dE": -0.4,
}

EE_nuis_params = {
    "a_gee": 0.10,
    "a_psee": 0,
    "alpha_dE": -0.4,
    "calE_LAT_93": 1,
    "calE_LAT_145": 1,
    "calE_LAT_225": 1,
}

# %%
namedir = packages_path + "/data/soliket_mflike/smooth_data/split_mflike/"
pre = "data_sacc_"
mflike_options = {
    "data_folder": namedir,
    "input_file": pre + "smooth_00000.fits",
    "cov_Bbl_file": packages_path + "/data/MFLike/v0.8/data_sacc_w_covar_and_Bbl.fits",
    "defaults": {
        "polarizations": ["TT", "TE", "ET", "EE"],
        "scales": {
            "TT": [30, 9000],
            "TE": [30, 9000],
            "ET": [30, 9000],
            "EE": [30, 9000],
        },
        "symmetrize": False,
    },
}

lensing_options = {
    "data_filename": "soliket_lensing/smooth_data/"
    "clkk_reconstruction_sim_frommulti_smooth.fits",
    "theory_lmax": 5000,
    "name": "kk",
    "stop_at_error": True,
}

info_multi_noxcov = {
    "likelihood": {
        "soliket.gaussian.MultiGaussianLikelihood": {
            "components": ["mflike.TTTEEE", "soliket.LensingLikelihood"],
            "options": [mflike_options, lensing_options],
            "stop_at_error": True,
        }
    },
    "theory": {
        "camb": {
            "extra_args": {
                "bbn_predictor": "PArthENoPE_880.2_standard.dat",
                "WantTransfer": True,
                "Transfer.high_precision": True,
                "Transfer.kmax": 1.2,
                "halofit_version": "mead",
                "lens_potential_accuracy": 1,
                "num_massive_neutrinos": 1,
                "theta_H0_range": [20, 100],
            },
            "stop_at_error": True,
        }
    },
    "params": cosmo_params
    | common_nuis_params
    | TT_nuis_params
    | TE_nuis_params
    | EE_nuis_params,
    "packages_path": packages_path,
    "debug": False,
}
info_multi_noxcov["theory"]["mflike.BandpowerForeground"] = {"stop_at_error": True}

xcovpath = "../cross_cov/products/"

info_multi_xcov = {
    "likelihood": {
        "soliket.gaussian.MultiGaussianLikelihood": {
            "components": ["mflike.TTTEEE", "soliket.LensingLikelihood"],
            "options": [mflike_options, lensing_options],
            "cross_cov_path": xcovpath + "XCov_full_sacc.fits",
            "stop_at_error": True,
        }
    },
    "theory": {
        "camb": {
            "extra_args": {
                "bbn_predictor": "PArthENoPE_880.2_standard.dat",
                "WantTransfer": True,
                "Transfer.high_precision": True,
                "Transfer.kmax": 1.2,
                "halofit_version": "mead",
                "lens_potential_accuracy": 1,
                "num_massive_neutrinos": 1,
                "theta_H0_range": [20, 100],
            },
            "stop_at_error": True,
        }
    },
    "params": cosmo_params
    | common_nuis_params
    | TT_nuis_params
    | TE_nuis_params
    | EE_nuis_params,
    "packages_path": packages_path,
    "debug": False,
}
info_multi_xcov["theory"]["mflike.BandpowerForeground"] = {"stop_at_error": True}

# %%
from cobaya.model import get_model

model_multi_noxcov = get_model(info_multi_noxcov)

# %% [markdown]
# Here, you can see how to create a multi-Gaussian covariance that includes cross-covariance between mflike and lensing.

# %%
import ast

from soliket.gaussian.gaussian import bandpower_ids
from soliket.gaussian.gaussian_data import CrossCov

mflike_like = model_multi_noxcov.components[0].likelihoods[0]
lensing_like = model_multi_noxcov.components[0].likelihoods[1]

mflike_data = mflike_like._get_gauss_data()
lensing_data = lensing_like._get_gauss_data()


def _cut_ids(data, like):
    # Per-bandpower identity keys at the (cut) data-vector granularity, so the
    # cross-covariance can later be aligned to the data by identity rather than
    # by position. SOLikeT likelihoods populate ``GaussianData.ids``
    # automatically; external ones (mflike) are handled by ``bandpower_ids``.
    keys = data.ids if data.ids is not None else bandpower_ids(like)
    if keys is None:
        return None
    if len(keys) == len(data):
        return list(keys)
    # full-range keys -> restrict to the kept bandpowers, in data order
    return [k for k, keep in zip(keys, data.indices) if keep]


mflike_ids = _cut_ids(mflike_data, mflike_like)
lensing_ids = _cut_ids(lensing_data, lensing_like)

# Create CrossCov and add components with their covariances + identity keys
crosscov = CrossCov()

# Add mflike component
crosscov.add_component(
    name=mflike_data.name, cov=mflike_data.cov, ids=mflike_ids
)

# Add lensing component
crosscov.add_component(
    name=lensing_data.name, cov=lensing_data.cov, ids=lensing_ids
)

# Load old cross-covariance from NPZ
xcovpath = "../cross_cov/products/"
old_xcov_file = xcovpath + "XCov_full.npz"

# Use ast.literal_eval for safe parsing of tuple keys
old_cov = {ast.literal_eval(k): v for k, v in np.load(old_xcov_file).items()}
cross_cov_matrix = old_cov[("mflike", "kk")]

# Trim cross-covariance to match component shapes. The trimmed rows are in the
# mflike data-vector order, so they line up with ``mflike_ids``.
cross_cov_trimmed = cross_cov_matrix[mflike_data.indices, :][:, lensing_data.indices]

# Add the cross-covariance, labelling each axis by identity
crosscov.add_cross_covariance(
    mflike_data.name,
    lensing_data.name,
    cross_cov_trimmed,
    ids1=mflike_ids,
    ids2=lensing_ids,
)

# Save to SACC format (identity keys are persisted in the file metadata)
crosscov.save(xcovpath + "XCov_full_sacc.fits")

# %%
model_multi_xcov = get_model(info_multi_xcov)

# %%
print(model_multi_noxcov.loglikes())
print(model_multi_xcov.loglikes())

# %%
like = model_multi_xcov.likelihood["soliket.gaussian.MultiGaussianLikelihood"]
params = {
    **cosmo_params,
    **common_nuis_params,
    **TT_nuis_params,
    **EE_nuis_params,
    **TE_nuis_params,
}
theory = like._get_theory(**params)
delta = like.data.data.y - theory
like.data._fast_chi_squared(like.data.inv_cov, delta)

# %%
like = model_multi_noxcov.likelihood["soliket.gaussian.MultiGaussianLikelihood"]
params = {
    **cosmo_params,
    **common_nuis_params,
    **TT_nuis_params,
    **EE_nuis_params,
    **TE_nuis_params,
}
theory = like._get_theory(**params)
delta = like.data.data.y - theory
like.data._fast_chi_squared(like.data.inv_cov, delta)

# %% [markdown]
# # Working with cross-covariances and ordering — the full picture
#
# The cell above builds a *real* mflike×lensing cross-covariance. This
# section is a small, self-contained illustration (no cosmology needed) of
# **what `CrossCov` does about ordering and why you must label blocks with
# identity keys**.
#
# Key ideas:
#
# - Every block carries per-bandpower **identity keys** (`ids1`/`ids2`, and
#   `ids=` on `add_component`). For real likelihoods these come from
#   `bandpower_ids(like)` / `GaussianData.ids` — *never* an ad-hoc scheme.
# - Blocks may be stored in **any order**; they are reconciled **by identity**,
#   not by position. So your cross-covariance can be computed in whatever
#   order an external code produced it, as long as you label it honestly.
# - `save()` lays the file out in a single **canonical order**, realigning
#   every block and **warning** you about each one it had to reorder.
# - At runtime `MultiGaussianData` realigns everything to the **live data
#   order** (the order the theory vector is built in).

# %%
# --- A self-contained toy example (no cosmology needed) -------------------
import numpy as np
import matplotlib.pyplot as plt

from soliket.gaussian.gaussian_data import CrossCov

# Two toy probes: A has 6 bandpowers, B has 4.
nA, nB = 6, 4


def spd(n, seed):
    M = np.random.default_rng(seed).standard_normal((n, n))
    return M @ M.T + n * np.eye(n)


cov_A = spd(nA, 1)
cov_B = spd(nB, 2)
# A clearly-structured cross block so a row reordering is visible by eye:
# row i is the constant 10*(i+1), columns add 0..nB-1.
cross_AB = np.add.outer(np.arange(1, nA + 1) * 10.0, np.arange(nB))

# Identity keys: (spectrum, tracer pair, ell-bin) -- the SAME scheme that
# bandpower_ids() produces for real likelihoods.
ids_A = [("cl_00", ("A", "A"), float(i)) for i in range(nA)]
ids_B = [("cl_00", ("B", "B"), float(i)) for i in range(nB)]

# %% [markdown]
# Now suppose your cross-covariance was computed in a **different bandpower
# order** than the data vector (very common when the matrix comes from an
# external NPZ). You know that order, so you label it honestly with permuted
# ids. The auto-covariance, meanwhile, is in the data order.

# %%
perm = [3, 0, 5, 1, 4, 2]              # the order your computation produced
cross_stored = cross_AB[perm, :]       # rows physically in 'perm' order
ids_A_perm = [ids_A[i] for i in perm]  # ...labelled to match

cc = CrossCov()
cc.add_component("A", cov_A, ids=ids_A)   # auto in DATA order
cc.add_component("B", cov_B, ids=ids_B)
cc.add_cross_covariance("A", "B", cross_stored, ids1=ids_A_perm, ids2=ids_B)

# %% [markdown]
# ### Before vs after reordering
#
# If you trusted **positions** and pasted the stored block next to the auto
# (which is in data order), the cross block's rows would be scrambled relative
# to the diagonal — a silent error. Aligning **by identity** (what
# `to_canonical`/`save` do) restores the clean row gradient.

# %%
naive = cross_stored                       # as-stored, wrongly assumed aligned
reconciled = cc.to_canonical({"A": ids_A, "B": ids_B})[:nA, nA:]  # by identity

fig, axes = plt.subplots(1, 3, figsize=(12, 4))
for ax, M, title in zip(
    axes,
    [naive, reconciled, reconciled - naive],
    ["stored order (mis-aligned)", "reconciled to data order", "difference"],
):
    im = ax.imshow(M, aspect="auto", cmap="viridis")
    ax.set_title(title)
    ax.set_xlabel("B bandpower")
    ax.set_ylabel("A bandpower")
    fig.colorbar(im, ax=ax)
plt.tight_layout()

# The reconciled block restores rows 10, 20, 30, ...; the stored one has them
# shuffled by 'perm'. They differ -> identity alignment matters.
assert np.allclose(reconciled, cross_AB)
print("reconciled matches the intended cross block:", np.allclose(reconciled, cross_AB))

# %% [markdown]
# ### `save()` reconciles and warns
#
# Because the auto block labels A in data order but the cross block labels A in
# `perm` order, `save()` picks a canonical order, realigns the cross block to
# it, and **warns** — naming the block and the permutation. Reloading and
# assembling reproduces the intended matrix.

# %%
import os
import tempfile
import warnings

path = os.path.join(tempfile.gettempdir(), "toy_xcov.sacc.fits")
with warnings.catch_warnings(record=True) as caught:
    warnings.simplefilter("always")
    cc.save(path)                  # picks canonical order, realigns, WARNS
for w in caught:
    print("warning:", w.message)

loaded = CrossCov.load(path)
full = loaded.to_canonical({"A": ids_A, "B": ids_B})
print("round-trips to data order:", np.allclose(full[:nA, nA:], cross_AB))

# %% [markdown]
# ### What this means for your real cross-covariance
#
# The mflike×lensing build a few cells up is the same workflow, with the toy
# `("cl_00", ...)` keys replaced by `bandpower_ids(like)` / `GaussianData.ids`.
# The rules:
#
# - **Always pass identity keys** (`ids1`/`ids2`, `ids=`) from `bandpower_ids`
#   — never plain integers or an ad-hoc `(freq, ell)` scheme — so blocks
#   align by identity and any mismatch fails loudly instead of silently.
# - Your cross-covariance may be computed in **any order**; label it honestly
#   and `save()` reconciles it, telling you which block it realigned.
# - If a component's blocks carry genuinely **different bandpower sets** (not
#   just a different order), `save()` raises — that is a real inconsistency
#   no reordering can fix.
# - You may **omit the auto-components** and store only the cross term;
#   `MultiGaussianData` then takes the autos from the live likelihoods and
#   aligns the cross block to the data by identity at runtime.
